# %% [markdown]
# ## Imports

# %%
import neural_network as nn
import scipy.io
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Load and process training samples.

# %%
mat_data = scipy.io.loadmat('digits_data/hand_written_digits.mat')
X = mat_data['X']
y = mat_data['y']
augmented_matrix = np.append(X, y, axis=1)
np.random.shuffle(augmented_matrix)
X = augmented_matrix[:, :-1]
y = augmented_matrix[:, -1]

# %% [markdown]
# ## Setup trainer

# %%
# Learning rate
alpha = 0.3
# Regularization
lamb = 100
# Random Theta rang
EPSILON_INIT = 0

digits_nn = nn.NeuralNetwork(X, y, alpha, lamb, EPSILON_INIT, 25)

# %% [markdown]
# ## Start training

# %%
digits_nn.train(iter_limit=300, time_limit=3600 * 7, grad_check=True, save_to_file=False)
# Out:
# Started training...
# Started gradient checking...
# Checking 100 randomly selected thetas...
# Gradient check passed.
# Used 1.21s for gradient checking.
# --------------------------------------------------
# | Iteration: 2
# | Cost of training set: 7.645563955586136
# | Cost of cross validation set: 4.335830330592513
# | Accuracy of testing set: 18.40%
# --------------------------------------------------
# Iteration 10, time passed 3.96s...
# Iteration 20, time passed 6.8s...
# Iteration 30, time passed 9.65s...
# Iteration 40, time passed 12.57s...
# Iteration 50, time passed 15.48s...
# Iteration 60, time passed 18.38s...
# Iteration 70, time passed 21.18s...
# Iteration 80, time passed 24.11s...
# Iteration 90, time passed 26.95s...
# Iteration 100, time passed 29.88s...
# --------------------------------------------------
# | Iteration: 100
# | Cost of training set: 2.5351096229553223
# | Cost of cross validation set: 4.807739566415432
# | Accuracy of testing set: 83.70%
# --------------------------------------------------
# Iteration 110, time passed 32.75s...
# Iteration 120, time passed 35.5s...
# Iteration 130, time passed 38.37s...
# Iteration 140, time passed 41.21s...
# Iteration 150, time passed 43.95s...
# Iteration 160, time passed 46.61s...
# Iteration 170, time passed 49.36s...
# Iteration 180, time passed 52.11s...
# Iteration 190, time passed 54.76s...
# Iteration 200, time passed 57.48s...
# --------------------------------------------------
# | Iteration: 200
# | Cost of training set: 2.3570047391255695
# | Cost of cross validation set: 4.811852205566693
# | Accuracy of testing set: 86.50%
# --------------------------------------------------
# Iteration 210, time passed 60.29s...
# Iteration 220, time passed 63.01s...
# Iteration 230, time passed 65.77s...
# Iteration 240, time passed 68.55s...
# Iteration 250, time passed 71.44s...
# Iteration 260, time passed 74.35s...
# Iteration 270, time passed 77.22s...
# Iteration 280, time passed 80.0s...
# Iteration 290, time passed 82.88s...
# Iteration 300, time passed 85.78s...
# --------------------------------------------------
# | Iteration: 300
# | Cost of training set: 2.309160155614217
# | Cost of cross validation set: 4.831890351913943
# | Accuracy of testing set: 86.80%
# --------------------------------------------------
# --------------------------------------------------
# Finished training, time used: 86.08189415931702s
# Accuracy of testing set: 86.80%
# --------------------------------------------------

# %% [markdown]
# ## Print an example of prediction.

# %%
print('Expected: {0}'.format(y[-10:-1]))
print('Prediction: {0}'.format(digits_nn.predict(np.matrix(X[-10:-1]))))
# Out:
# Expected: [  4.  10.   9.  10.   1.   7.   2.  10.   3.]
# Prediction: [[  4.  10.   9.  10.   1.   7.   3.  10.   3.]]

# %% [markdown]
# ## Plot cost and accuracy graph.

# %%
digits_nn.plot_training_info(color='#00BFFF')
digits_nn.show_plot()

# %% [markdown]
# ## Visualize Theta

# %%
digits_nn.visualize_Theta(cmap='Greys_r', origin='lower')
digits_nn.show_plot()
